# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import UnigramTagger,BigramTagger,pos_tag
from nltk.corpus import treebank
from nltk import pos_tag_sents
# Out:
# Name : Aryan Pilwalkar UIN : 231A016

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt_tab')
nltk.download('treebank')
nltk.download('tagsets_json')
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# [nltk_data] Downloading package tagsets_json to /root/nltk_data...
# [nltk_data]   Package tagsets_json is already up-to-date!
# True

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
sample_text = "A bottomless, suffocating blackness that swallows the light, hiding ancient things that hold their breath and watch you drown."

tokens = word_tokenize(sample_text)
# Out:
# Name : Aryan Pilwalkar UIN : 231A016

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
rule_based_tags = pos_tag(tokens)
print(rule_based_tags)
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# [('A', 'DT'), ('bottomless', 'NN'), (',', ','), ('suffocating', 'VBG'), ('blackness', 'NN'), ('that', 'WDT'), ('swallows', 'VBZ'), ('the', 'DT'), ('light', 'NN'), (',', ','), ('hiding', 'VBG'), ('ancient', 'JJ'), ('things', 'NNS'), ('that', 'WDT'), ('hold', 'VBP'), ('their', 'PRP$'), ('breath', 'NN'), ('and', 'CC'), ('watch', 'NN'), ('you', 'PRP'), ('drown', 'VBP'), ('.', '.')]

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
nltk.help.upenn_tagset("JJ")
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
#statistical tagging using treebank corpus trained perceptron tagger
train_sents = treebank.tagged_sents()

#unigram tagger
unigram_tagger = UnigramTagger(train_sents)
unigram_tag = unigram_tagger.tag(tokens)

#bigram tagger
bigram_tagger = BigramTagger(train_sents)
bigram_tag = bigram_tagger.tag(tokens)
# Out:
# Name : Aryan Pilwalkar UIN : 231A016

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
unigram_tag
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# [('A', 'DT'),
#  ('bottomless', None),
#  (',', ','),
#  ('suffocating', None),
#  ('blackness', None),
#  ('that', 'IN'),
#  ('swallows', None),
#  ('the', 'DT'),
#  ('light', 'JJ'),
#  (',', ','),
#  ('hiding', None),
#  ('ancient', 'JJ'),
#  ('things', 'NNS'),
#  ('that', 'IN'),
#  ('hold', 'VB'),
#  ('their', 'PRP$'),
#  ('breath', None),
#  ('and', 'CC'),
#  ('watch', 'NN'),
#  ('you', 'PRP'),
#  ('drown', None),
#  ('.', '.')]

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
bigram_tag
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# [('A', 'DT'),
#  ('bottomless', None),
#  (',', None),
#  ('suffocating', None),
#  ('blackness', None),
#  ('that', None),
#  ('swallows', None),
#  ('the', None),
#  ('light', None),
#  (',', None),
#  ('hiding', None),
#  ('ancient', None),
#  ('things', None),
#  ('that', None),
#  ('hold', None),
#  ('their', None),
#  ('breath', None),
#  ('and', None),
#  ('watch', None),
#  ('you', None),
#  ('drown', None),
#  ('.', None)]

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
print("original Sentence:",sample_text)
print("\nRule Based Tagging:",rule_based_tags)
print("\nUnigram Tagging:",unigram_tag)
print("\nBigram Tagging:",bigram_tag)
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# original Sentence: A bottomless, suffocating blackness that swallows the light, hiding ancient things that hold their breath and watch you drown.
#
# Rule Based Tagging: [('A', 'DT'), ('bottomless', 'NN'), (',', ','), ('suffocating', 'VBG'), ('blackness', 'NN'), ('that', 'WDT'), ('swallows', 'VBZ'), ('the', 'DT'), ('light', 'NN'), (',', ','), ('hiding', 'VBG'), ('ancient', 'JJ'), ('things', 'NNS'), ('that', 'WDT'), ('hold', 'VBP'), ('their', 'PRP$'), ('breath', 'NN'), ('and', 'CC'), ('watch', 'NN'), ('you', 'PRP'), ('drown', 'VBP'), ('.', '.')]
#
# Unigram Tagging: [('A', 'DT'), ('bottomless', None), (',', ','), ('suffocating', None), ('blackness', None), ('that', 'IN'), ('swallows', None), ('the', 'DT'), ('light', 'JJ'), (',', ','), ('hiding', None), ('ancient', 'JJ'), ('things', 'NNS'), ('that', 'IN'), ('hold', 'VB'), ('their', 'PRP$'), ('breath', None), ('and', 'CC'), ('watch', 'NN'), ('you', 'PRP'), ('drown', None), ('.', '.')]
#
# Bigram Tagging: [('A', 'DT'), ('bottomless', None), (',', None), ('suffocating', None), ('blackness', None), ('that', None), ('swallows', None), ('the', None), ('light', None), (',', None), ('hiding', None), ('ancient', None), ('things', None), ('that', None), ('hold', None), ('their', None), ('breath', None), ('and', None), ('watch', None), ('you', None), ('drown', None), ('.', None)]

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
test_sents = treebank.tagged_sents()[3000:]
unigram_acc = unigram_tagger.accuracy(test_sents)
print(f"Unigram Accuracy:{unigram_acc*100:.2f}%")
bigram_acc = bigram_tagger.accuracy(test_sents)
print(f"Bigram Accuracy:{bigram_acc*100:.2f}%")
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# Unigram Accuracy:96.32%
# Bigram Accuracy:92.16%

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
pos_tag(["class"])
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# [('class', 'NN')]
