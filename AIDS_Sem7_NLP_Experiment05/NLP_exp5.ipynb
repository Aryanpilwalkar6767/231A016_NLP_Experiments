# %% [markdown]
# ##Part 1

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
import nltk
from nltk import word_tokenize, bigrams, FreqDist, ConditionalFreqDist
from nltk.corpus import stopwords
from collections import defaultdict

#Download necessary NLTK resources
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')

#Step 1: Load and preprocess the text corpus
def preprocess(text):
    #convert to lower case
    text = text.lower()
    #tokenization
    tokens = word_tokenize(text)
    #remove punctuations and stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token.isalnum() and token not in stop_words]
    return tokens
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
#The quick brown fox jumps over the lazy dog. The fox is quick and dog is lazy.
corpus = "Science is a most fast growing field. Engineering and architecture make the basic necessity of survival. Engineering is one of the most opted technology field. Engineering has contributed in a large manner. Architecture provided the basic foundation of human civilization.Engineering and architecture are hence required to sustain humanity"
test = "Engineering is a fast growing field"
tokens = preprocess(corpus)
print(tokens)
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# ['science', 'fast', 'growing', 'field', 'engineering', 'architecture', 'make', 'basic', 'necessity', 'survival', 'engineering', 'one', 'opted', 'technology', 'field', 'engineering', 'contributed', 'large', 'manner', 'architecture', 'provided', 'basic', 'foundation', 'human', 'architecture', 'hence', 'required', 'sustain', 'humanity']

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
#Generate Bigrams
bigrams_list = list(bigrams(tokens))
print(bigrams_list)
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# [('science', 'fast'), ('fast', 'growing'), ('growing', 'field'), ('field', 'engineering'), ('engineering', 'architecture'), ('architecture', 'make'), ('make', 'basic'), ('basic', 'necessity'), ('necessity', 'survival'), ('survival', 'engineering'), ('engineering', 'one'), ('one', 'opted'), ('opted', 'technology'), ('technology', 'field'), ('field', 'engineering'), ('engineering', 'contributed'), ('contributed', 'large'), ('large', 'manner'), ('manner', 'architecture'), ('architecture', 'provided'), ('provided', 'basic'), ('basic', 'foundation'), ('foundation', 'human'), ('human', 'architecture'), ('architecture', 'hence'), ('hence', 'required'), ('required', 'sustain'), ('sustain', 'humanity')]

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
#Calculate bigram frequency
bigrams_freq = FreqDist(bigrams_list)
bigrams_freq
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# FreqDist({('field', 'engineering'): 2, ('science', 'fast'): 1, ('fast', 'growing'): 1, ('growing', 'field'): 1, ('engineering', 'architecture'): 1, ('architecture', 'make'): 1, ('make', 'basic'): 1, ('basic', 'necessity'): 1, ('necessity', 'survival'): 1, ('survival', 'engineering'): 1, ...})

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
#Calculate conditional frequencies to predict next word
cfd = ConditionalFreqDist(bigrams_list)
print(cfd.items())
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# dict_items([('science', FreqDist({'fast': 1})), ('fast', FreqDist({'growing': 1})), ('growing', FreqDist({'field': 1})), ('field', FreqDist({'engineering': 2})), ('engineering', FreqDist({'architecture': 1, 'one': 1, 'contributed': 1})), ('architecture', FreqDist({'make': 1, 'provided': 1, 'hence': 1})), ('make', FreqDist({'basic': 1})), ('basic', FreqDist({'necessity': 1, 'foundation': 1})), ('necessity', FreqDist({'survival': 1})), ('survival', FreqDist({'engineering': 1})), ('one', FreqDist({'opted': 1})), ('opted', FreqDist({'technology': 1})), ('technology', FreqDist({'field': 1})), ('contributed', FreqDist({'large': 1})), ('large', FreqDist({'manner': 1})), ('manner', FreqDist({'architecture': 1})), ('provided', FreqDist({'basic': 1})), ('foundation', FreqDist({'human': 1})), ('human', FreqDist({'architecture': 1})), ('hence', FreqDist({'required': 1})), ('required', FreqDist({'sustain': 1})), ('sustain', FreqDist({'humanity': 1}))])

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
from nltk import trigrams
trigrams_list = list(trigrams(tokens))
print(trigrams_list)
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# ...

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
trigrams_freq = FreqDist(trigrams_list)
trigrams_freq
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# FreqDist({('science', 'fast', 'growing'): 1, ('fast', 'growing', 'field'): 1, ('growing', 'field', 'engineering'): 1, ('field', 'engineering', 'architecture'): 1, ('engineering', 'architecture', 'make'): 1, ('architecture', 'make', 'basic'): 1, ('make', 'basic', 'necessity'): 1, ('basic', 'necessity', 'survival'): 1, ('necessity', 'survival', 'engineering'): 1, ('survival', 'engineering', 'one'): 1, ...})

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
#Function to predict the next word based on a given word
def predict_next_word(word):
    word = word.lower()
    if word in cfd:
        next_words = cfd[word].max()
        return next_words
    else:
        return "Word not found in the corpus"
# Out:
# Name : Aryan Pilwalkar UIN : 231A016

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
#Test the prediction function
start_word = "science"
next_word = predict_next_word(start_word)
print(f"The next word after '{start_word}' is '{next_word}'.")
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# The next word after 'science' is 'fast'.

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
#Generate a sequence of words
def generate_sequence(start_word, num_words):
    sequence = [start_word]
    currnet_word = start_word
    for _ in range(num_words):
        next_word = predict_next_word(currnet_word)
        if next_word == "Word not found in the corpus":
            break
        sequence.append(next_word)
        currnet_word = next_word
    return " ".join(sequence)
# Out:
# Name : Aryan Pilwalkar UIN : 231A016

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
#Generate a word starting from science
generated_sequence = generate_sequence("science", 9)
print(f"Generated sequence starting from '{start_word}': {generated_sequence}")
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# Generated sequence starting from 'science': science fast growing field engineering architecture make basic necessity survival

# %% [markdown]
# ##Part 2

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
import nltk
from nltk.corpus import reuters
from nltk import bigrams, FreqDist, ConditionalFreqDist, trigrams, ngrams
from collections import defaultdict

nltk.download('reuters')
nltk.download('punkt')
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# [nltk_data] Downloading package reuters to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
file_ids = reuters.fileids()
print(len(file_ids))
print(file_ids[:10])
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# 10788
# ['test/14826', 'test/14828', 'test/14829', 'test/14832', 'test/14833', 'test/14839', 'test/14840', 'test/14841', 'test/14842', 'test/14843']

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
print(len(reuters.words()))
print(reuters.words()[91:100])
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# 1720901
# ['the', 'conflict', 'would', 'hurt', 'them', 'in', 'the', 'long', '-']

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
words = reuters.words(file_ids[10787])
print(words)
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# ['&', 'lt', ';', 'A', '.', 'H', '.', 'A', '.', ...]

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
words = nltk.word_tokenize(" ".join(reuters.words()))
print(len(words))
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# 1728932

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
#Create Trigrams
tri_grams = list(trigrams(words))
print(tri_grams[:10])
# Out:
# Name : Aryan Pilwalkar UIN : 231A016

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
model = defaultdict(lambda: defaultdict(lambda: 0))
# Out:
# Name : Aryan Pilwalkar UIN : 231A016

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
# Count frequency of co-occurrence
tri_grams = list(trigrams(words))
for w1, w2, w3 in tri_grams:
    model[(w1, w2)][w3] += 1
# Out:
# Name : Aryan Pilwalkar UIN : 231A016

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
# Transform counts into probabilities
for w1_w2 in model:
    total_count = sum(model[w1_w2].values())

    for w3 in model[w1_w2]:
        model[w1_w2][w3] /= total_count
# Out:
# Name : Aryan Pilwalkar UIN : 231A016

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
# Function to predict the next word
def predict_next_word(w1, w2):
    next_words = model.get((w1, w2), {})

    if next_words:
        return max(next_words, key=next_words.get)
    else:
        return "Word not found in the corpus"
# Out:
# Name : Aryan Pilwalkar UIN : 231A016

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
print(predict_next_word("the", "price"))
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# of

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
import math

def calculate_perplexity(test_sentence):
    test_tokens = word_tokenize(test_sentence)

    log_prob_sum = 0

    for i in range(2, len(test_tokens)):
        w1 = test_tokens[i - 2]
        w2 = test_tokens[i - 1]
        w3 = test_tokens[i]

        prob = model[(w1, w2)].get(w3, 1e-10)

        log_prob_sum += math.log(prob)

    perplexity = math.exp(-log_prob_sum / (len(test_tokens) - 2))

    return perplexity
# Out:
# Name : Aryan Pilwalkar UIN : 231A016

# %%
print("Name : Aryan Pilwalkar UIN : 231A016")
test_sentence = "ASIAN EXPORTERS FEAR DAMAGE"

perplexity = calculate_perplexity(test_sentence)

print("Test Sentence:", test_sentence)
print("Perplexity:", perplexity)
# Out:
# Name : Aryan Pilwalkar UIN : 231A016
# Test Sentence: ASIAN EXPORTERS FEAR DAMAGE
# Perplexity: 1.0
