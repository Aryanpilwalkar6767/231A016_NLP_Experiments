# %% [markdown]
# #Experiment no 7
# date - 3 / 8 / 2026

# %% [markdown]
# #Part 2

# %%
print("Name: Aryan Pilwalkar UIN:231A016")
import nltk

nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("maxent_ne_chunker_tab")
nltk.download("words")
nltk.download("averaged_perceptron_tagger_eng")
nltk.download("tagsets_json")
# Out:
# Name: Aryan Pilwalkar UIN:231A016
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package tagsets_json to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets_json.zip.
# True

# %%
print("Name: Aryan Pilwalkar UIN:231A016")

from nltk import word_tokenize,pos_tag,ne_chunk
# Out:
# Name: Aryan Pilwalkar UIN:231A016

# %%
print("Name: Aryan Pilwalkar UIN:231A016")
text = "The Natural Language Toolkit, or more commonly NLTK, is a wonderful suite of libraries for Python! Dr. John Doe, an expert in AI, visited M.I.T. last Tuesday at 3:00 PM. He spoke about text-processing, running algorithms, and how computers are learning beautifully from human data. Aren't these technologies changing India rapidly?"
print(text)
# Out:
# Name: Aryan Pilwalkar UIN:231A016
# The Natural Language Toolkit, or more commonly NLTK, is a wonderful suite of libraries for Python! Dr. John Doe, an expert in AI, visited M.I.T. last Tuesday at 3:00 PM. He spoke about text-processing, running algorithms, and how computers are learning beautifully from human data. Aren't these technologies changing India rapidly?

# %%
print("Name: Aryan Pilwalkar UIN:231A016")
tokens = word_tokenize(text)
print(tokens)
# Out:
# Name: Aryan Pilwalkar UIN:231A016
# ['The', 'Natural', 'Language', 'Toolkit', ',', 'or', 'more', 'commonly', 'NLTK', ',', 'is', 'a', 'wonderful', 'suite', 'of', 'libraries', 'for', 'Python', '!', 'Dr.', 'John', 'Doe', ',', 'an', 'expert', 'in', 'AI', ',', 'visited', 'M.I.T', '.', 'last', 'Tuesday', 'at', '3:00', 'PM', '.', 'He', 'spoke', 'about', 'text-processing', ',', 'running', 'algorithms', ',', 'and', 'how', 'computers', 'are', 'learning', 'beautifully', 'from', 'human', 'data', '.', 'Are', "n't", 'these', 'technologies', 'changing', 'India', 'rapidly', '?']

# %%
print("Name: Aryan Pilwalkar UIN:231A016")
tagged_tokens = pos_tag(tokens)
print(tagged_tokens)
# Out:
# Name: Aryan Pilwalkar UIN:231A016
# [('The', 'DT'), ('Natural', 'NNP'), ('Language', 'NNP'), ('Toolkit', 'NNP'), (',', ','), ('or', 'CC'), ('more', 'JJR'), ('commonly', 'RB'), ('NLTK', 'NNP'), (',', ','), ('is', 'VBZ'), ('a', 'DT'), ('wonderful', 'JJ'), ('suite', 'NN'), ('of', 'IN'), ('libraries', 'NNS'), ('for', 'IN'), ('Python', 'NNP'), ('!', '.'), ('Dr.', 'NNP'), ('John', 'NNP'), ('Doe', 'NNP'), (',', ','), ('an', 'DT'), ('expert', 'NN'), ('in', 'IN'), ('AI', 'NNP'), (',', ','), ('visited', 'VBD'), ('M.I.T', 'NNP'), ('.', '.'), ('last', 'JJ'), ('Tuesday', 'NNP'), ('at', 'IN'), ('3:00', 'CD'), ('PM', 'NNP'), ('.', '.'), ('He', 'PRP'), ('spoke', 'VBD'), ('about', 'IN'), ('text-processing', 'NN'), (',', ','), ('running', 'VBG'), ('algorithms', 'NN'), (',', ','), ('and', 'CC'), ('how', 'WRB'), ('computers', 'NNS'), ('are', 'VBP'), ('learning', 'VBG'), ('beautifully', 'RB'), ('from', 'IN'), ('human', 'JJ'), ('data', 'NNS'), ('.', '.'), ('Are', 'VBP'), ("n't", 'RB'), ('these', 'DT'), ('technologies', 'NNS'), ('changing', 'VBG'), ('India', 'NNP'), ('rapidly', 'RB'), ('?', '.')]

# %%
print("Name: Aryan Pilwalkar UIN:231A016")
nltk.help.upenn_tagset("DT")
nltk.help.upenn_tagset("VBZ")
# Out:
# Name: Aryan Pilwalkar UIN:231A016
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...

# %%
print("Name: Aryan Pilwalkar UIN:231A016")
named_entities = ne_chunk(tagged_tokens)
print(named_entities)
# Out:
# Name: Aryan Pilwalkar UIN:231A016
# (S
#   The/DT
#   (ORGANIZATION Natural/NNP Language/NNP Toolkit/NNP)
#   ,/,
#   or/CC
#   more/JJR
#   commonly/RB
#   (ORGANIZATION NLTK/NNP)
#   ,/,
#   is/VBZ
#   a/DT
#   wonderful/JJ
#   suite/NN
#   of/IN
#   libraries/NNS
#   for/IN
#   (PERSON Python/NNP)
#   !/.
#   Dr./NNP
#   (PERSON John/NNP Doe/NNP)
#   ,/,
#   an/DT
#   expert/NN
#   in/IN
#   (GPE AI/NNP)
#   ,/,
#   visited/VBD
#   M.I.T/NNP
#   ./.
#   last/JJ
#   Tuesday/NNP
#   at/IN
#   3:00/CD
#   PM/NNP
#   ./.
#   He/PRP
#   spoke/VBD
#   about/IN
#   text-processing/NN
#   ,/,
#   running/VBG
#   algorithms/NN
#   ,/,
#   and/CC
#   how/WRB
#   computers/NNS
#   are/VBP
#   learning/VBG
#   beautifully/RB
#   from/IN
#   human/JJ
#   data/NNS
#   ./.
#   Are/VBP
#   n't/RB
#   these/DT
#   technologies/NNS
#   changing/VBG
#   (GPE India/NNP)
#   rapidly/RB
#   ?/.)

# %%
print("Name: Aryan Pilwalkar UIN:231A016")
for subtree in named_entities:
  if isinstance(subtree,nltk.Tree):
    entity = "".join([word for word,tag in subtree.leaves()])
    label = subtree.label()
    print(f"Entity:{entity}, Label: {label}")
# Out:
# Name: Aryan Pilwalkar UIN:231A016
# Entity:NaturalLanguageToolkit, Label: ORGANIZATION
# Entity:NLTK, Label: ORGANIZATION
# Entity:Python, Label: PERSON
# Entity:JohnDoe, Label: PERSON
# Entity:AI, Label: GPE
# Entity:India, Label: GPE

# %%
print("Name: Aryan Pilwalkar UIN:231A016")
# !pip install svgling --quiet
# Out:
# Name: Aryan Pilwalkar UIN:231A016
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 7.7 MB/s eta 0:00:00

# %%
print("Name: Aryan Pilwalkar UIN:231A016")
named_entities = ne_chunk(tagged_tokens)
named_entities
# Out:
# Name: Aryan Pilwalkar UIN:231A016
# Tree('S', [('The', 'DT'), Tree('ORGANIZATION', [('Natural', 'NNP'), ('Language', 'NNP'), ('Toolkit', 'NNP')]), (',', ','), ('or', 'CC'), ('more', 'JJR'), ('commonly', 'RB'), Tree('ORGANIZATION', [('NLTK', 'NNP')]), (',', ','), ('is', 'VBZ'), ('a', 'DT'), ('wonderful', 'JJ'), ('suite', 'NN'), ('of', 'IN'), ('libraries', 'NNS'), ('for', 'IN'), Tree('PERSON', [('Python', 'NNP')]), ('!', '.'), ('Dr.', 'NNP'), Tree('PERSON', [('John', 'NNP'), ('Doe', 'NNP')]), (',', ','), ('an', 'DT'), ('expert', 'NN'), ('in', 'IN'), Tree('GPE', [('AI', 'NNP')]), (',', ','), ('visited', 'VBD'), ('M.I.T', 'NNP'), ('.', '.'), ('last', 'JJ'), ('Tuesday', 'NNP'), ('at', 'IN'), ('3:00', 'CD'), ('PM', 'NNP'), ('.', '.'), ('He', 'PRP'), ('spoke', 'VBD'), ('about', 'IN'), ('text-processing', 'NN'), (',', ','), ('running', 'VBG'), ('algorithms', 'NN'), (',', ','), ('and', 'CC'), ('how', 'WRB'), ('computers', 'NNS'), ('are', 'VBP'), ('learning', 'VBG'), ('beautifully', 'RB'), ('from', 'IN'), ('human', 'JJ'), ('data', 'NNS'), ('.', '.'), ('Are', 'VBP'), ("n't", 'RB'), ('these', 'DT'), ('technologies', 'NNS'), ('changing', 'VBG'), Tree('GPE', [('India', 'NNP')]), ('rapidly', 'RB'), ('?', '.')])

# %%
print("Name: Aryan Pilwalkar UIN:231A016")
import spacy

nlp = spacy.load("en_core_web_sm")

text = "The Natural Language Toolkit, or more commonly NLTK, is a wonderful suite of libraries for Python! Dr. John Doe, an expert in AI, visited M.I.T. last Tuesday at 3:00 PM. He spoke about text-processing, running algorithms, and how computers are learning beautifully from human data. Aren't these technologies changing India rapidly?"

doc = nlp(text)

for ent in doc.ents:
  print(f"Entity:{ent.text},label:{ent.label_}")
# Out:
# Name: Aryan Pilwalkar UIN:231A016
# Entity:The Natural Language Toolkit,label:ORG
# Entity:NLTK,label:ORG
# Entity:John Doe,label:PERSON
# Entity:AI,label:GPE
# Entity:last Tuesday,label:DATE
# Entity:3:00 PM,label:TIME
# Entity:India,label:GPE

# %% [markdown]
# #part 1

# %%
print("Name: Aryan Pilwalkar UIN:231A016")
import nltk
from nltk import pos_tag, word_tokenize
from nltk.chunk import RegexpParser
# Out:
# Name: Aryan Pilwalkar UIN:231A016

# %%
print("Name: Aryan Pilwalkar UIN:231A016")
sentence_1 = "The quick brown fox jumps over the lazy dog"
sentence_2 = "This is the class of natural language processing."
# Out:
# Name: Aryan Pilwalkar UIN:231A016

# %%
print("Name: Aryan Pilwalkar UIN:231A016")
tokens = word_tokenize(sentence_2)
tagged = pos_tag(tokens)
tagged
# Out:
# Name: Aryan Pilwalkar UIN:231A016
# [('This', 'DT'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('class', 'NN'),
#  ('of', 'IN'),
#  ('natural', 'JJ'),
#  ('language', 'NN'),
#  ('processing', 'NN'),
#  ('.', '.')]

# %%
print("Name: Aryan Pilwalkar UIN:231A016")
grammer_1 = "NP: {<DT>?<JJ>*<NN>}"
# Out:
# Name: Aryan Pilwalkar UIN:231A016

# %%
print("Name: Aryan Pilwalkar UIN:231A016")
chunk_parser = RegexpParser(grammer_1)
chunked = chunk_parser.parse(tagged)

print(chunked)
# Out:
# Name: Aryan Pilwalkar UIN:231A016
# (S
#   This/DT
#   is/VBZ
#   (NP the/DT class/NN)
#   of/IN
#   (NP natural/JJ language/NN)
#   (NP processing/NN)
#   ./.)

# %%
print("Name: Aryan Pilwalkar UIN:231A016")
from nltk.tree import Tree
import svgling

# For displaying the chunked tree, we use svgling.draw_tree()
svgling.draw_tree(chunked)
# Out:
# Name: Aryan Pilwalkar UIN:231A016
# TreeLayout(Tree('S', [('This', 'DT'), ('is', 'VBZ'), Tree('NP', [('the', 'DT'), ('class', 'NN')]), ('of', 'IN'), Tree('NP', [('natural', 'JJ'), ('language', 'NN')]), Tree('NP', [('processing', 'NN')]), ('.', '.')]))

# %%
print("Name: Aryan Pilwalkar UIN:231A016")
grammer_2 = "VP: {<MD>?<VB.*><RB.*><VB.*>*}"
chunk_parser = RegexpParser(grammer_2)
chunked1 = chunk_parser.parse(tagged)
# Out:
# Name: Aryan Pilwalkar UIN:231A016

# %%
print("Name: Aryan Pilwalkar UIN:231A016")
print(chunked1)
import svgling
svgling.draw_tree(chunked1)
# Out:
# Name: Aryan Pilwalkar UIN:231A016
# (S
#   This/DT
#   is/VBZ
#   the/DT
#   class/NN
#   of/IN
#   natural/JJ
#   language/NN
#   processing/NN
#   ./.)
# TreeLayout(Tree('S', [('This', 'DT'), ('is', 'VBZ'), ('the', 'DT'), ('class', 'NN'), ('of', 'IN'), ('natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('.', '.')]))

# %%
nltk.help.upenn_tagset("MD*")
# Out:
# MD: modal auxiliary
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would
